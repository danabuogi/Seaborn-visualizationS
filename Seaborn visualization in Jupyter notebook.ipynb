# %%
import seaborn as sns

# %%
sns.get_dataset_names()

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
planets = sns.load_dataset("planets")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
g = sns.scatterplot(x="tip", y="total_bill", data=tips, hue="day", size="size")

# %%
sns.histplot(tips["tip"],kde=True,bins=10, color = "orange")
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="sex",y="tip",data=tips)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,hue="sex",palette="YlGnBu")
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="tip",data=tips,hue="sex",palette="YlGnBu",dodge=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x="tip",y="total_bill",data=tips)

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="reg")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="kde")

# %% [markdown]
# # Notes
# - In the above map, as you go further out, the less instances you have.
# - below if you add fill is equal to True you can see where the highest concentration is.

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="kde",fill=True, color="navy")

# %% [markdown]
# # Note
# - You can also add a cmap color as below

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="kde",fill=True, color="navy",cmap="YlGnBu")

# %% [markdown]
# # Note
# - You can also change the kind to hex as shown below.
# - However, you are to remove fill because a hex does not have fill.

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="hex", color="navy",cmap="YlGnBu")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(titanic.select_dtypes(["number"]),hue="pclass")

# %% [markdown]
# # Note
# - The pairplot above is important if you are trying to understand your data.
# - Pictures speak a thousand words

# %%
titanic.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11724\2964377706.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# ...

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="YlGnBu")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11724\3601765712.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="YlGnBu")
# <AxesSubplot: >

# %% [markdown]
# # Note
# - The heatmap below is a good visual for showing correlations.
# - In the above heatmap, whatever is strongly correlated is close to blue and weak correlation is donoted with the yellow or toward yellow.

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="coolwarm")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11724\2635739876.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="coolwarm")
# <AxesSubplot: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="icefire")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11724\1269812426.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="icefire")
# <AxesSubplot: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="rocket")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11724\2606893950.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="rocket")
# <AxesSubplot: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="mako")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11724\107813157.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="mako")
# <AxesSubplot: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="cubehelix")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11724\814465906.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="cubehelix")
# <AxesSubplot: >
